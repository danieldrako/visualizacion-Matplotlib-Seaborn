# %% [markdown]
# <a href="https://colab.research.google.com/github/danieldrako/visualizacion-Matplotlib-Seaborn/blob/main/05Leyendas_etiquetas_t%C3%ADtulos_tama%C3%B1o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Cómo dar contexto a los gráficos
# Para dar contexto a nuestros gráficos necesitamos usar títulos, leyendas, tamaño o etiquetas, para que nuestra gráfica tenga un contexto más amplio.
#
#
# - Creamos nuestras gráficas comunes

# %%
import matplotlib.pyplot as plt
import numpy as np 
x = np.linspace(0,5,11)
y = np.sin(x)

# %% [markdown]
# ###Contexto a los gráficos con títulos
# Para crear los títulos realiza lo siguiente:

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.plot(x,y, 'b')
ax1.set_title("Relacion X - Y")

ax2.plot(y,x, 'r')
ax2.set_title("Relacion Y - X")
# Out:
# Text(0.5, 1.0, 'Relacion Y - X')

# %% [markdown]
# ###Contexto agregando etiquetas
# Agrega labels en los ejes

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.plot(x,y, 'b', )
ax1.set_title("Relacion X - Y")
ax1.set_xlabel("X")
ax1.set_ylabel("Y")

ax2.plot(y,x, 'r')
ax2.set_title("Relacion Y - X")
ax2.set_xlabel("Y")
ax2.set_ylabel("X")
# Out:
# Text(0, 0.5, 'X')

# %% [markdown]
# ###Cambiar el tamaño a las figuras
# Realiza la siguiente acción:

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize= (1,5))

# %% [markdown]
# ### Aplicar etiquetas (por defecto pone la mejor opción)

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.plot(x,y, 'b', label = "sin(x)")
ax1.set_title("Relacion X - Y")
ax1.set_xlabel("X")
ax1.set_ylabel("Y")
ax1.legend()
ax2.plot(y,x, 'r', label = "arcsin(x)")
ax2.set_title("Relacion Y - X")
ax2.set_xlabel("Y")
ax2.set_ylabel("X")
ax2.legend()

# %% [markdown]
# ###* Modificar la localización de la etiqueta

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.plot(x,y, 'b', label = "sin(x)")
ax1.set_title("Relacion X - Y")
ax1.set_xlabel("X")
ax1.set_ylabel("Y")
ax1.legend(loc = "upper center")
ax2.plot(y,x, 'r', label = "$sin^{-1}(x)$")
ax2.set_title("Relacion Y - X")
ax2.set_xlabel("Y")
ax2.set_ylabel("X")
ax2.legend()

# %% [markdown]
# ###Otras ubicaciones
#
#
# |upper right	|upper left|	lower left|	lower right|	right|
# |-------------|----------|------------|------------|-------|
